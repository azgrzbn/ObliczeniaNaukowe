# %% [markdown]
# <a href="https://colab.research.google.com/github/azgrzbn/ObliczeniaNaukowe/blob/main/Praca%20domowa%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L1=[1,10,2,15,22,112]
L2=[0.5,1,15,22.4,22,211]

L1=sorted(L1)
L2=sorted(L2)
print (L1,L2)

L3=[]
for i in range(len(L1)):
    L3.append(str(L1[i])+str(L2[i]))
print(L3)
# Out:
# [1, 2, 10, 15, 22, 112] [0.5, 1, 15, 22, 22.4, 211]
# ['10.5', '21', '1015', '1522', '2222.4', '112211']

# %%
Jarek = set(('koty', 'dobrze zjesc', 'piwo', 'bose spacery po trawie', 'pilka nozna'))
Marek = set(('piwo', 'psy', 'dobrze zjesc', 'siatkowka', 'seriale'))
print (Jarek, Marek)

print(Jarek.intersection(Marek))
# Out:
# {'bose spacery po trawie', 'dobrze zjesc', 'piwo', 'koty', 'pilka nozna'} {'psy', 'dobrze zjesc', 'piwo', 'siatkowka', 'seriale'}
# {'dobrze zjesc', 'piwo'}

# %%
import random
def listownik():
    n=int(input("podaj liczbe od 10 do 20 :"))
    if n>20 or n<10:
        k="Zła liczba!"
    else:
        k=[]
        for i in range(n):
            k.append(random.randrange(0, 10, 1))
    print (k) 
listownik()
# Out:
# podaj liczbe od 10 do 20 :12
# [9, 6, 4, 3, 2, 4, 3, 3, 9, 1, 4, 9]
